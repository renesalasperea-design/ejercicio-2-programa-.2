# %% [markdown]
# <a href="https://colab.research.google.com/github/renesalasperea-design/ejercicio-2-programa-.2/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
palabra = input("Ingresa una palabra: ")

invertida = palabra[::-1]

if palabra == invertida:
    print("La palabra es un palíndromo")
else:
    print("La palabra NO es un palíndromo")
# Out:
# Ingresa una palabra: oso
# La palabra es un palíndromo
